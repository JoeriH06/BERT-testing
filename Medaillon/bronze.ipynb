# %% [markdown]
# #  This is the bronze layer where we gather the data.
#
# In our case we have pre-made datasets, these datasets where made by AI.
# The datasets that where created are in blob-format, with the ID, Title, and content sepperated.

# %%
# First we will import the libraries.
import pandas as pd
import os
import json

# %%
# Then we will read the data from the Data folder. These JSON files are untouched and raw data.
# we will read the data into a pandas dataframe for easier manipulation and analysis.

bronze_data = pd.DataFrame()

for file in os.listdir('../Data/raw'):
    if file.endswith('.json'):
        with open(os.path.join('../Data/raw', file), 'r') as f:
            data = json.load(f)
            bronze_data = pd.concat([bronze_data, pd.DataFrame([data])], ignore_index=True)

# we check if the data is loaded correctly by displaying the first few rows of the dataframe.
bronze_data.head(10)
# Out:
#        id                                              title  \
# 0  doc_01  Assessing Climate Adaptation Measures in Low-L...
# 1  doc_02  Evaluating Circular Economy Practices in Regio...
# 2  doc_03  Data Integration Challenges in Cross-Sector Re...
# 3  doc_04  Designing Indicators for Municipal Climate Res...
# 4  doc_05  Improving Data Literacy Through Applied Educat...
# 5  doc_06  Assessing the Impact of Nature-Based Solutions...
# 6  doc_07  Challenges in Monitoring Water Quality Using L...
# 7  doc_08  Stakeholder Engagement in Regional Energy Tran...
# 8  doc_09  Developing a Knowledge Platform for Research R...
# 9  doc_10  Assessing the Use of Dashboards for Decision S...
#
#                                              content
# 0  Introduction\nClimate adaptation has become a ...
# 1  Introduction\nThe circular economy seeks to re...
# 2  Introduction\nCross-sector research collaborat...
# 3  Introduction\nMunicipalities play a crucial ro...
# 4  Introduction\nData literacy has become an esse...
# 5  Introduction\nUrban heat stress has emerged as...
# 6  Introduction\nWater quality monitoring is esse...
# 7  Introduction\nThe transition from fossil-based...
# 8  Introduction\nResearch projects generate a lar...
# 9  Introduction\nDashboards have become a common ...

# %%
# Now that we put the bronze data into a dataframe, we can go on to the silver layer.
# This silver layer needs to bronze dataframe so we have to pass this through to the next notebook.

bronze_data.to_csv('../Data/bronze/bronze_data.csv', index=False)
